# %% [markdown]
# # Artistas que mais venderam discos no Brasil
#
# Este relatório é um exemplo de análise de dados com python. Analisaremos os dados [nessa lista de artistas da Wikipedia](https://pt.wikipedia.org/wiki/Lista_de_recordistas_de_vendas_de_discos_no_Brasil).

# %%
import pandas as pd
import seaborn as sns

# %%
vendas_artistas = pd.read_csv("https://orionwinter.github.io/datasets/vendas_artistas_br.csv")

# %%
vendas_artistas.sort_values(by = "vendas", ascending = False)
# Out:
#                         artista  ... vendas
# 1                Roberto Carlos  ...  120.0
# 2              Nelson Gonçalves  ...   75.0
# 3                      Rita Lee  ...   55.0
# 0               Tonico & Tinoco  ...   50.0
# 4                    Nelson Ned  ...   45.0
# 5                          Xuxa  ...   40.0
# 6   Leonardo/Leandro e Leonardo  ...   35.0
# 7          Chitãozinho e Xororó  ...   30.0
# 8                    Raça Negra  ...   30.0
# 9                Maria Bethânia  ...   26.0
# 10                Legião Urbana  ...   25.0
# 11               Mara Maravilha  ...   23.0
# 12                Amado Batista  ...   22.0
# 13    Zezé Di Camargo & Luciano  ...   20.0
# 14               Sandy & Junior  ...   17.0
# 15                 Fábio Júnior  ...   16.0
# 16                Banda Calypso  ...   15.0
# 17                        Pitty  ...   15.0
# 18                    Sepultura  ...   15.0
# 19                Ivete Sangalo  ...   15.0
# 20              Roberta Miranda  ...   14.0
# 21                     Angélica  ...   13.0
# 22               Zeca Pagodinho  ...   12.0
# 30                        Wando  ...   10.0
# 29        Turma do Balão Mágico  ...   10.0
# 28                 Marisa Monte  ...   10.0
# 27                  Lulu Santos  ...   10.0
# 26              Diante do Trono  ...   10.0
# 24               Calcinha Preta  ...   10.0
# 23              Alexandre Pires  ...   10.0
# 25               Carmen Miranda  ...   10.0
# 31                   Kid Abelha  ...    9.0
# 32              Bruno & Marrone  ...    9.0
# 33                Fafá de Belém  ...    9.0
# 34                  Exaltasamba  ...    8.0
# 35          Padre Marcelo Rossi  ...    8.0
# 36              Rose Nascimento  ...    8.0
# 37                   Roupa Nova  ...    8.0
# 38           Shirley Carvalhaes  ...    8.0
# 39            Só pra Contrariar  ...    8.0
# 43              Daniela Mercury  ...    7.0
# 44                     Cassiane  ...    7.0
# 40                          KLB  ...    7.0
# 42                 Aline Barros  ...    7.0
# 41                         Belo  ...    7.0
# 45                        Titãs  ...    6.3
# 46               Deborah Blando  ...    6.0
# 47              Trazendo a Arca  ...    6.0
# 48                        Rouge  ...    6.0
# 49                        Skank  ...    5.5
# 50                 Ana Carolina  ...    5.0
# 51            Charlie Brown Jr.  ...    5.0
# 52      Os Paralamas do Sucesso  ...    5.0
# 53                    Raimundos  ...    5.0
#
# [54 rows x 5 columns]

# %% [markdown]
# Artista: Roberto Carlos  |
# Vendas: 120.0
