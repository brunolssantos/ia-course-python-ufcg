# %% [markdown]
# # Atividade sobre Classificação utilizando Redes Neurais
#
# Para esta atividade, utilize como base [este tutorial](https://www.tensorflow.org/tutorials/keras/classification?hl=pt-br) e a aula sobre [Classificação no Fashion MNIST com Keras](https://www.youtube.com/watch?v=7Do1OEn7Q6U).
#
# Siga os seguintes passos para realizar a atividade:
#
# - Utilizando a base de dados Fashion MNIST, treine 3 modelos de Redes Neurais utilizando diferentes combinações de quantidade de camadas e neurônios por camadas, e compare-os com base em acurácia e perda no teste.
# - Escolha um desses modelos como o melhor, justificando sua escolha.
# - Realize predições utilizado o modelo escollhido. Utilize as funções implementadas [nesta seção](https://colab.research.google.com/github/tensorflow/docs-l10n/blob/master/site/pt/tutorials/keras/classification.ipynb?hl=pt-br#scrollTo=xsoS7CPDCaXH) do tutorial para mostrar graficamente algumas previsões.

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

train_images = train_images/255
test_images = test_images/255

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ##Modelos

# %% [markdown]
# ###Modelo 1

# %%
model1 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model1.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model1.fit(train_images, train_labels, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 4s 64us/sample - loss: 0.4997 - acc: 0.8259
# Epoch 2/10
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.3779 - acc: 0.8635
# Epoch 3/10
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.3402 - acc: 0.8758
# Epoch 4/10
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.3153 - acc: 0.8856
# Epoch 5/10
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.2965 - acc: 0.8903
# Epoch 6/10
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.2815 - acc: 0.8957
# Epoch 7/10
# 60000/60000 [==============================] - 4s 60us/sample - loss: 0.2694 - acc: 0.9003
# Epoch 8/10
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.2575 - acc: 0.9020
# Epoch 9/10
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.2466 - acc: 0.9083
# Epoch 10/10
# ...

# %% [markdown]
# ###Modelo 2

# %%
model2 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model2.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model2.fit(train_images, train_labels, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 4s 67us/sample - loss: 0.4941 - acc: 0.8231
# Epoch 2/10
# 60000/60000 [==============================] - 4s 61us/sample - loss: 0.3672 - acc: 0.8653
# Epoch 3/10
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.3306 - acc: 0.8769
# Epoch 4/10
# 60000/60000 [==============================] - 4s 63us/sample - loss: 0.3084 - acc: 0.8859
# Epoch 5/10
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.2937 - acc: 0.8905
# Epoch 6/10
# 60000/60000 [==============================] - 4s 61us/sample - loss: 0.2797 - acc: 0.8953
# Epoch 7/10
# 60000/60000 [==============================] - 4s 64us/sample - loss: 0.2674 - acc: 0.8997
# Epoch 8/10
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.2557 - acc: 0.9029
# Epoch 9/10
# 60000/60000 [==============================] - 4s 64us/sample - loss: 0.2477 - acc: 0.9063
# Epoch 10/10
# ...

# %% [markdown]
# ###Modelo 3

# %%
model3 = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model3.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model3.fit(train_images, train_labels, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.4957 - acc: 0.8199
# Epoch 2/10
# 60000/60000 [==============================] - 4s 65us/sample - loss: 0.3698 - acc: 0.8645
# Epoch 3/10
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.3373 - acc: 0.8754
# Epoch 4/10
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.3135 - acc: 0.8828
# Epoch 5/10
# 60000/60000 [==============================] - 4s 66us/sample - loss: 0.2968 - acc: 0.8891
# Epoch 6/10
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.2828 - acc: 0.8940
# Epoch 7/10
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.2698 - acc: 0.9002
# Epoch 8/10
# 60000/60000 [==============================] - 4s 72us/sample - loss: 0.2595 - acc: 0.9021
# Epoch 9/10
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.2494 - acc: 0.9066
# Epoch 10/10
# ...

# %% [markdown]
# ##Comparação e Escolha

# %%
test_loss, test_acc = model1.evaluate(test_images,  test_labels, verbose=2)
print('\nTest model1 accuracy:', test_acc)
test_loss, test_acc = model2.evaluate(test_images,  test_labels, verbose=2)
print('\nTest model2 accuracy:', test_acc)
test_loss, test_acc = model3.evaluate(test_images,  test_labels, verbose=2)
print('\nTest model3 accuracy:', test_acc)
# Out:
# 10000/10000 - 0s - loss: 0.3293 - acc: 0.8874
#
# Test model1 accuracy: 0.8874
# 10000/10000 - 0s - loss: 0.3427 - acc: 0.8787
#
# Test model2 accuracy: 0.8787
# 10000/10000 - 0s - loss: 0.3498 - acc: 0.8764
#
# Test model3 accuracy: 0.8764

# %% [markdown]
# Baseado nos dados de loss de accuracia, o melhor modelo é o 1 com uma camada escondida de 128 neuronios.

# %% [markdown]
# ##Predições com o melhor modelo

# %%
predictions = model1.predict(test_images)

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array[i], true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array[i], true_label[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions, test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions, test_labels)
plt.show()
